# %% [markdown]
# <a href="https://colab.research.google.com/github/Pantercode/Analise_exploratoria_titanic/blob/main/Analise_Exploratoria_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#Importando datasets
df1 = pd.read_csv('train.csv', sep=',')

# %%
#Visualizando os dados
display(df1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#primeiras linhas
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 3 ultimas linhas
df1.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#verificando o tamanho da base
df1.shape
# Out:
# (891, 12)

# %%
#vizualindo o resumo das informações
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#contando a quantidade de valores nulos
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#conferindo as descrições estatitisticas
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Cardinalidade ajuda a saber a quantidade dos dados distintos em uma coluna

# %%
#Verificando a quantidade de valores diferentes na base
df1.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # vizualindo de forma grafica

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# Graficar la barra con bordes blancos
ax.bar(df1.nunique().index, df1.nunique().values)


ax.tick_params(axis='x',labelrotation=75)

# Mostrar el gráfico
plt.show()

# %%
#vizulizando de forma descrescente
df1.nunique().sort_values(ascending=False).index
# Out:
# Index(['PassengerId', 'Name', 'Ticket', 'Fare', 'Cabin', 'Age', 'SibSp',
#        'Parch', 'Pclass', 'Embarked', 'Survived', 'Sex'],
#       dtype='object')

# %%
# Ordem decrescente

fig, ax = plt.subplots()

# Graficar la barra con bordes blancos
ax.bar(df1.nunique().sort_values(ascending=False).index, df1.nunique().sort_values(ascending=False).values)

ax.tick_params(axis='x', labelrotation=75)

# Mostrar el gráfico
plt.show()

# %%
#verificando tarifas
fig, ax = plt.subplots()

#bins intervalos
ax.hist(df1.Fare, bins=30)

plt.show()

# %%
#verificando tarifas
fig, ax = plt.subplots()

#bins intervalos
ax.hist(df1[df1.Fare < 100].Fare, bins=20)

plt.show()

# %%
#df1.loc[df1.Fare > 100].Fare

# %%
#podemos qualquer valor de um dos valores do describe
df1.Fare.describe()['75%']
# Out:
# 31.0

# %%
#determinando o interquartil
Q1 = df1.Fare.describe()['25%']
Q3 = df1.Fare.describe()['75%']
interquartil = Q3 -Q1

#calculando o valor máximo
vlr_max = Q3 + 1.5* interquartil

# %%
#outliers não são valores errados e sim distantes
vlr_max
# Out:
# 65.6344

# %%
df1[df1.Fare > vlr_max]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#contando o numero de linhas da base
df1.shape[0]/4
# Out:
# 222.75

# %%
#Verificando a quantidade de registros em cada intervalo (<Q1, entre Q1 e Q2, entre Q2 e Q3,>Q3)
Q2 = df1.Fare.describe()['50%']
df1[(df1.Fare > Q2 ) & ( df1.Fare < Q3)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 10                Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11                       Bonnell, Miss. Elizabeth  female  58.0      0      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# ...

# %%
# Boxplot analisa simetria e percentis ex outliers

fig, ax = plt.subplots(ncols=2, figsize=(12,8))

ax[0].boxplot(df1.Fare)
ax[1].boxplot([df1.SibSp,df1.Parch])

plt.show()

# %%
#verificando o value_counts

df1.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#verificando o resumo estatisco da coluna

df1.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.Pclass.value_counts().index
# Out:
# Int64Index([3, 1, 2], dtype='int64')

# %%
#Analise de PClass
fig, ax = plt.subplots()

x= df1.Pclass.value_counts().index.astype('str')
y= df1.Pclass.value_counts().values

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)



plt.show()

# %%
#Verificando se existe relação entre a coluna Parch e a idade


fig, ax = plt.subplots()



x= df1.Parch
y= df1.Age
ax.scatter(x, y)

plt.show()

# %%
#Criando uma matriz para mostrar a correlação de cada par de variaveis
#pd.plotting.scatter_matrix(df1, figsize=(16,12))
#plt.show()

# %%
import seaborn as sns

# %%
#Criando uma matriz para mostrar a correlação de cada par de variaveis
sns.pairplot(df1, hue='Survived', diag_kind='hist')
plt.show()

# %%
#fazendo kde  Pclass
sns.kdeplot(df1.Pclass)
plt.show()

# %%
#fazendo kde  com e sem survived
sns.kdeplot(df1.Fare)
plt.show()

# %%
# Criar o gráfico com KDE e histograma com o tamanho desejado
plt.figure(figsize=(10, 6))
sns.histplot(df1['Fare'], kde=True)

# Mostrar o gráfico
plt.show()

# %%
#correlação dos dados
df1.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#Heatmap
sns.heatmap(df1.corr(),annot=True,cmap='RdYlGn')

plt.show()

# %%
#tratando outliers


fig, ax = plt.subplots()

ax.boxplot(df1.Fare)


plt.show()

# %%
#filtrando pessoas que pagaram mais de 300
df1[df1.Fare > 300]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#filtrando pessoas que pagaram menos de 1
df1[df1.Fare < 1]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
#calculando a media Fare
mean_fare = df1.Fare.mean().round()

# %%
#substituindo valores
df1.loc[df1.Fare < 1, 'Fare'] = mean_fare

# %%
#verficando os valores nulos
df1[df1.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#Analisando a base
df1.loc[df1.Age.isnull(), 'Survived'].value_counts()
# Out:
# 0    125
# 1     52
# Name: Survived, dtype: int64

# %%
#calculando a media das idades
df1.Age.mean()
# Out:
# 29.69911764705882

# %%
df1.loc[df1.Age.isnull(),'Age'] = df1.Age.mean()

# %%
#conferindo a novamente a analise
df1[df1.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
